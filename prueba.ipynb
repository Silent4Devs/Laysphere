# %%
# import
from langchain.embeddings.sentence_transformer import SentenceTransformerEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.document_loaders import UnstructuredPowerPointLoader

# load the document and split it into chunks
loader = UnstructuredPowerPointLoader("C:/Users/antonio.gutierrez/Documents/Layla_Sphere/database/CV S4B Completo_Español_06.2023.pptx")
documents = loader.load()

# split it into chunks
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

# create the open-source embedding function
embedding_function = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

# load it into Chroma
db = Chroma.from_documents(docs, embedding_function)

# query it
query = "¿Cual es la mision de silent4business?"
docs = db.similarity_search(query)

#save to disk
db2 = Chroma.from_documents(docs, embedding_function, persist_directory="./chroma_db")
docs = db2.similarity_search(query)

# load from disk
db3 = Chroma(persist_directory="./chroma_db", embedding_function=embedding_function)
docs = db3.similarity_search(query)

# print results
print(docs[0].page_content)
# Out:
# Pruebas de penetración y Análisis de vulnerabilidad.
#
# 3
#
# 4
#
# Ciclo de desarrollo seguro.
#
# Servicios de Ingeniería Social.
#
# SERVICIO DE CIBERINTELIGENCIA
#
# Es una solución de ciberinteligencia que permite conocer  proactivamente las amenazas a las que se encuentra  expuesta tu organización mediante un monitoreo  permanente del ciberespacio.
#
# Brand Protection
#
# LKKL Ç´
#
# Identificación y seguimiento de sitios phishing.
#
# Monitoreo de aplicaciones apócrifas.
#
# Identificación de credenciales comprometidas.
#
# Deep Threat Analysis
#
# Monitoreo de amenazas (Malware, C&C, Blacklist,  Exploit kit).
#
# Cyber Threat Alert
#
# Seguimiento de vulnerabilidades.
#
# Notificaciones de noticias de ciberseguridad.Identificación de fuga de información.
#
# SOLUCIONES TECNOLÓGICAS
#
# En Silent4Business ofrecemos las siguientes Soluciones  Tecnológicas:
#
# Protección Perimetral (Firewall, IPS/IDS,  Balanceadores, Filtrado de Contenido y Correo,  DDoS, entre otros).
# Pruebas de penetración y Análisis de vulnerabilidad.
#
# 3
#
# 4
#
# Ciclo de desarrollo seguro.
#
# Servicios de Ingeniería Social.
#
# SERVICIO DE CIBERINTELIGENCIA
#
# Es una solución de ciberinteligencia que permite conocer  proactivamente las amenazas a las que se encuentra  expuesta tu organización mediante un monitoreo  permanente del ciberespacio.
#
# Brand Protection
#
# LKKL Ç´
#
# Identificación y seguimiento de sitios phishing.
#
# Monitoreo de aplicaciones apócrifas.
#
# Identificación de credenciales comprometidas.
#
# Deep Threat Analysis
#
# Monitoreo de amenazas (Malware, C&C, Blacklist,  Exploit kit).
#
# Cyber Threat Alert
#
# Seguimiento de vulnerabilidades.
#
# Notificaciones de noticias de ciberseguridad.Identificación de fuga de información.
#
# SOLUCIONES TECNOLÓGICAS
#
# En Silent4Business ofrecemos las siguientes Soluciones  Tecnológicas:
#
# Protección Perimetral (Firewall, IPS/IDS,  Balanceadores, Filtrado de Contenido y Correo,  DDoS, entre otros).
